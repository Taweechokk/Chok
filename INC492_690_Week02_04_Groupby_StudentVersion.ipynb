# %% [markdown]
# <a href="https://colab.research.google.com/github/Taweechokk/INC492/blob/main/INC492_690_Week02_04_Groupby_StudentVersion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INC492/690: Introduction to Data Science**
#
# Week02 - Python for Data Science
# -----------------------------------
# Dr. Teema Leangarun
#
# Department of Controls System and Instrumentation Engineering
#
# Facullty of Engineering, KMUTT

# %% [markdown]
# # Groupby
#
# The groupby method allows you to group rows of data together and call aggregate functions

# %%
import pandas as pd
# Create dataframe
data ={'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['A','B','C','D','E','F'],
       'Sales':[200,120,340,124,243,350]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   Company Person  Sales
# 0    GOOG      A    200
# 1    GOOG      B    120
# 2    MSFT      C    340
# 3    MSFT      D    124
# 4      FB      E    243
# 5      FB      F    350

# %% [markdown]
# ** Now you can use the .groupby() method to group rows together based off of a column name. For instance let's group based off of Company. This will create a DataFrameGroupBy object:**

# %%
by_comp =df.groupby

# %% [markdown]
# You can save this object as a new variable:

# %%
by_comp = df.groupby("Company")

# %% [markdown]
# And then call aggregate methods off the object:

# %%
by_comp.mean()
# Out:
# <ipython-input-6-15ce3fbdee9c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   by_comp.mean()
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
df.groupby("Company").mean()
# Out:
# <ipython-input-8-8406f2e73703>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Company").mean()
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %% [markdown]
# More examples of aggregate methods:

# %%
by_comp.std()
# Out:
# <ipython-input-9-795bdc0ea79d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   by_comp.std()
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
by_comp.min()
# Out:
#         Person  Sales
# Company
# FB           E    243
# GOOG         A    120
# MSFT         C    124

# %%
by_comp.max()
# Out:
#         Person  Sales
# Company
# FB           F    350
# GOOG         B    200
# MSFT         D    340

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
by_comp.describe().transpose()
# Out:
# Company              FB        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
by_comp.describe().transpose()['MSFT']
# Out:
# Sales  count      2.000000
#        mean     232.000000
#        std      152.735065
#        min      124.000000
#        25%      178.000000
#        50%      232.000000
#        75%      286.000000
#        max      340.000000
# Name: MSFT, dtype: float64

# %% [markdown]
# # Great Job!
