# %% [markdown]
# # **INC492-690: Introduction to Data Science for Automation Systems**
#
# Week09 - Supervised learning: Classification problems
# -----------------------------------
# Dr. Teema Leangarun
#
# Department of Controls System and Instrumentation Engineering
#
# Facullty of Engineering, KMUTT

# %%
# Import libraries
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

# %%
# Create dataset 1
# Out:
# First five rows and col values
# X1 :
#  [[2.51526543 1.11143935]
#  [1.8155981  1.11969719]
#  [2.69637316 0.62563218]
#  [1.67280531 0.65930057]
#  [1.89593761 5.18540259]]
#  y1 :
#  [ 1  1  1  1 -1]

# %%
# Create dataset 2
# Out:
# First five rows and col values
# X2 :
#  [[ 1.36184715 -0.41167231]
#  [ 0.13131691  1.05028173]
#  [-1.02116066  0.25546441]
#  [ 1.10418823 -0.37322465]
#  [ 1.89098756  0.04691886]]
#  y2 :
#  [ 1  1  1  1 -1]

# %%
# Create dataset 3
# Out:
# First five rows and col values
# X1 :
#  [[ 0.53366396 -0.1813877 ]
#  [ 0.37500898 -0.24743176]
#  [-0.53597135  0.87804743]
#  [ 0.80850547 -0.5781825 ]
#  [ 0.30414461 -0.47088602]]
#  y3 :
#  [ 1  1  1  1 -1]

# %%
# Create Support Vector Machine

    # let alpha = 0.001, lambda_ = 0.01, iterations = 1000

        # learning rate

        # tradeoff

        # number of iterations

        # weights or slopes

        # bias



        # initalizing with 0 (weight)

        # initialize with 0 (bias)



                # w(yi)(xi) - b ≥ 1

                  # w = w + α* (2λw - yixi)


                  # w = w + α* (2λw - yixi)

                  # b = b - α* (yi)






        # returning in the form of -1 and 1

# %%
# Create function for calculating hyperplane

# %%
# Create function for plotting

# %%
# Plot graph to show svm1
# Out:
# For dataset 1, score: 1.0

# %%
# Plot graph to show svm2
# Out:
# For dataset 2, score: 0.865

# %%
# Plot graph to show svm3
# Out:
# For dataset 3, score: 0.505
